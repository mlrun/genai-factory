# %% [markdown]
# # A2A Client Workflow Example
#
# This example demonstrates an intelligent Agent-to-Agent (A2A) workflow that automatically routes requests based on the type of conversation.
#
# ## Workflow Architecture
#
# ![Workflow Diagram](workflow_diagram.png)

# %% [markdown]
# ## Setup
#
# Before you start, make sure you have completed the following steps:
#
# 1. Install the required packages:

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: a2a-sdk==0.3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: httpx<1.0,>=0.24 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: fastapi>=0.95.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.110.3)
# Requirement already satisfied: google-api-core>=1.26.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: protobuf==5.29.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: pydantic>=2.11.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: sse-starlette in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: starlette in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.37.2)
# Requirement already satisfied: anyio in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpx<1.0,>=0.24->-r requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: certifi in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpx<1.0,>=0.24->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpx<1.0,>=0.24->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpx<1.0,>=0.24->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.24->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from fastapi>=0.95.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from anyio->httpx<1.0,>=0.24->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (2.43.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (1.26.20)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.0->-r requirements.txt (line 1)) (0.6.1)

# %%
# !pip install git+https://github.com/mlrun/genai-factory.git
# Out:
# Collecting git+https://github.com/mlrun/genai-factory.git
#   Cloning https://github.com/mlrun/genai-factory.git to /private/var/folders/rn/q8gs952n26982d36y50w_2rw0000gp/T/pip-req-build-yd7yhq_c
#   Running command git clone --filter=blob:none --quiet https://github.com/mlrun/genai-factory.git /private/var/folders/rn/q8gs952n26982d36y50w_2rw0000gp/T/pip-req-build-yd7yhq_c
#   Resolved https://github.com/mlrun/genai-factory.git to commit 1e90149bf7989e64860ab695e7582d785fef9749
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: langchain_community in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.3.31)
# Requirement already satisfied: langchain_openai in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.2.14)
# Requirement already satisfied: langchain_huggingface in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.1.2)
# Requirement already satisfied: pymilvus in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (2.5.17)
# Requirement already satisfied: langchain-milvus in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.1.7)
# Requirement already satisfied: fastapi>=0.103.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.110.3)
# Requirement already satisfied: mlrun==1.9.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (1.9.1)
# Requirement already satisfied: uvicorn==0.30.6 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from genai-factory==0.1) (0.30.6)
# Requirement already satisfied: urllib3<1.27,>=1.26.9 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.26.20)
# Requirement already satisfied: GitPython>=3.1.41,~=3.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.1.45)
# Requirement already satisfied: aiohttp~=3.11 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.13.2)
# Requirement already satisfied: aiohttp-retry~=2.9 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (2.9.1)
# Requirement already satisfied: click~=8.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (8.3.1)
# Requirement already satisfied: nest-asyncio~=1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.6.0)
# Requirement already satisfied: ipython~=8.10 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (8.37.0)
# Requirement already satisfied: nuclio-jupyter~=0.11.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.11.2)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (2.1.4)
# Requirement already satisfied: pyarrow<17,>=10.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (16.1.0)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (6.0.3)
# Requirement already satisfied: requests~=2.32 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (2.32.5)
# Requirement already satisfied: tabulate~=0.8.6 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.8.10)
# Requirement already satisfied: v3io~=0.7.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.7.2)
# Requirement already satisfied: pydantic>=1.10.15 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (2.12.5)
# Requirement already satisfied: mergedeep~=1.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.3.4)
# Requirement already satisfied: v3io-frames>=0.13.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.13.11)
# Requirement already satisfied: semver~=3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.0.4)
# Requirement already satisfied: dependency-injector~=4.41 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (4.48.2)
# Requirement already satisfied: fsspec<2024.7,>=2023.9.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (2024.6.1)
# Requirement already satisfied: v3iofs~=0.1.17 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.1.18)
# Requirement already satisfied: storey~=1.9.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.9.1)
# Requirement already satisfied: inflection~=0.5.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.5.1)
# Requirement already satisfied: python-dotenv~=1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.2.1)
# Requirement already satisfied: setuptools>=75.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (80.9.0)
# Requirement already satisfied: deprecated~=1.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (1.3.1)
# Requirement already satisfied: jinja2>=3.1.3,~=3.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.1.6)
# Requirement already satisfied: orjson<4,>=3.9.15 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.11.4)
# Requirement already satisfied: mlrun-pipelines-kfp-common~=0.4.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.4.4)
# Requirement already satisfied: mlrun-pipelines-kfp-v1-8~=0.4.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.4.3)
# Requirement already satisfied: docstring_parser~=0.16 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (0.17.0)
# Requirement already satisfied: aiosmtplib~=3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun==1.9.1->genai-factory==0.1) (3.0.2)
# Requirement already satisfied: h11>=0.8 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from uvicorn==0.30.6->genai-factory==0.1) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun==1.9.1->genai-factory==0.1) (1.22.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from deprecated~=1.2->mlrun==1.9.1->genai-factory==0.1) (1.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from GitPython>=3.1.41,~=3.1->mlrun==1.9.1->genai-factory==0.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.41,~=3.1->mlrun==1.9.1->genai-factory==0.1) (5.0.2)
# Requirement already satisfied: decorator in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (2.19.2)
# Requirement already satisfied: stack_data in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jinja2>=3.1.3,~=3.1->mlrun==1.9.1->genai-factory==0.1) (3.0.3)
# Requirement already satisfied: kfp_server_api~=1.8 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (1.8.5)
# Requirement already satisfied: kubernetes>=25.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (34.1.0)
# Requirement already satisfied: six>=1.10 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kfp_server_api~=1.8->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (1.17.0)
# Requirement already satisfied: certifi in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kfp_server_api~=1.8->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (2025.11.12)
# Requirement already satisfied: python-dateutil in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kfp_server_api~=1.8->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (2.9.0.post0)
# Requirement already satisfied: nbconvert>=6.4.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (7.16.6)
# Requirement already satisfied: boto3>=1.28.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.41.5)
# Requirement already satisfied: importlib-metadata<8.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (7.2.1)
# Requirement already satisfied: jupyter-server>=2.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2.17.0)
# Requirement already satisfied: ipykernel>=5.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from importlib-metadata<8.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun==1.9.1->genai-factory==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun==1.9.1->genai-factory==0.1) (2025.2)
# Requirement already satisfied: wcwidth in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from requests~=2.32->mlrun==1.9.1->genai-factory==0.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from requests~=2.32->mlrun==1.9.1->genai-factory==0.1) (3.11)
# Requirement already satisfied: xxhash>=1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from storey~=1.9.0->mlrun==1.9.1->genai-factory==0.1) (3.6.0)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from storey~=1.9.0->mlrun==1.9.1->genai-factory==0.1) (0.6.1)
# Requirement already satisfied: botocore<1.42.0,>=1.41.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.41.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.15.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from fastapi>=0.103.0->genai-factory==0.1) (0.37.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun==1.9.1->genai-factory==0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun==1.9.1->genai-factory==0.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun==1.9.1->genai-factory==0.1) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.103.0->genai-factory==0.1) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.103.0->genai-factory==0.1) (1.3.1)
# Requirement already satisfied: appnope>=0.1.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (5.9.1)
# Requirement already satisfied: packaging>=22 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (23.2)
# Requirement already satisfied: psutil>=5.7 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (6.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jedi>=0.16->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (4.5.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (25.1.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (4.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (4.0.0)
# Requirement already satisfied: referencing in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.37.0)
# Requirement already satisfied: rfc3339-validator in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.29.0)
# Requirement already satisfied: fqdn in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.1.0)
# Requirement already satisfied: uri-template in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (25.10.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (2.43.0)
# Requirement already satisfied: requests-oauthlib in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (0.6.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.5.1)
# Requirement already satisfied: webencodings in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pexpect>4.3->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.3.1)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun==1.9.1->genai-factory==0.1) (1.72.0)
# Requirement already satisfied: grpcio-tools>=1.49 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun==1.9.1->genai-factory==0.1) (1.76.0)
# Requirement already satisfied: protobuf<7,>=4 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from v3io-frames>=0.13.0->mlrun==1.9.1->genai-factory==0.1) (5.29.5)
# Collecting protobuf<7,>=4 (from v3io-frames>=0.13.0->mlrun==1.9.1->genai-factory==0.1)
#   Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: grpcio>=1.76.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from grpcio-tools>=1.49->v3io-frames>=0.13.0->mlrun==1.9.1->genai-factory==0.1) (1.76.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2.0.0)
# Requirement already satisfied: pycparser in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.1->mlrun==1.9.1->genai-factory==0.1) (1.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (0.3.80)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (2.0.44)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (0.4.49)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_community->genai-factory==0.1) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->genai-factory==0.1) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->genai-factory==0.1) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain<2.0.0,>=0.3.27->langchain_community->genai-factory==0.1) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community->genai-factory==0.1) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->genai-factory==0.1) (0.28.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->genai-factory==0.1) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->genai-factory==0.1) (0.25.0)
# Requirement already satisfied: httpcore==1.* in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community->genai-factory==0.1) (1.0.9)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community->genai-factory==0.1) (1.1.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_huggingface->genai-factory==0.1) (0.36.0)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_huggingface->genai-factory==0.1) (5.1.2)
# Requirement already satisfied: tokenizers>=0.19.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_huggingface->genai-factory==0.1) (0.22.1)
# Requirement already satisfied: transformers>=4.39.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_huggingface->genai-factory==0.1) (4.57.3)
# Requirement already satisfied: filelock in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface->genai-factory==0.1) (3.20.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface->genai-factory==0.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface->genai-factory==0.1) (1.2.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (2.9.1)
# Requirement already satisfied: scikit-learn in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (1.7.2)
# Requirement already satisfied: scipy in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (1.16.3)
# Requirement already satisfied: Pillow in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (12.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from transformers>=4.39.0->langchain_huggingface->genai-factory==0.1) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from transformers>=4.39.0->langchain_huggingface->genai-factory==0.1) (0.7.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (3.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (1.3.0)
# Requirement already satisfied: ujson>=2.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pymilvus->genai-factory==0.1) (5.11.0)
# Requirement already satisfied: milvus-lite>=2.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from pymilvus->genai-factory==0.1) (2.5.1)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_openai->genai-factory==0.1) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from langchain_openai->genai-factory==0.1) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai->genai-factory==0.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai->genai-factory==0.1) (0.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.4.4->mlrun==1.9.1->genai-factory==0.1) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface->genai-factory==0.1) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/Omer_Mimon/miniconda3/envs/genai-factory/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun==1.9.1->genai-factory==0.1) (0.2.3)
# Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# a2a-sdk 0.3.0 requires protobuf==5.29.5, but you have protobuf 6.33.2 which is incompatible.
# Successfully installed protobuf-6.33.2

# %%
# !export GENAI_FACTORY_ENV_PATH=$(pwd)/.env

# %%
# %%writefile .env
#
# # Configure your environment variables here
# A2A_BASE_URL='...' # Your Agent base URL (default "http://localhost:10000")
# OPENAI_BASE_URL='...'  # Your OpenAI base URL
# OPENAI_API_KEY='...'  # Your OpenAI API key
# GENAI_FACTORY_IS_LOCAL_CONFIG='...'  # Set to 'true' for local configuration
# GENAI_FACTORY_LOCAL_CHROMA='...'  # Path to local Chroma database (if applicable
# Out:
# Overwriting .env

# %% [markdown]
# ## Deploying the GenAI Factory
#
# The following command will start the API controller server and the UI server in a local Docker container. It will also initialize the controller database.

# %% [markdown]
# ```bash
# make up
# ```
#
# Run the above command in your terminal to deploy the GenAI Factory.

# %% [markdown]
# ### 4. Start the A2A Agent Server
#
# Start your A2A agent server (required for meeting conversation processing):
#
# ```bash
# Start your A2A agent server on http://localhost:10000
# ```

# %% [markdown]
# ## Deploying the Workflow

# %%
# Deploy the workflow defined in workflow.py
# !genai-factory run workflow.py
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Importing workflows server from: workflow.py
# Running workflows using a 'fastapi' runner...
# Building workflows
# INFO:     Started server process [65019]
# INFO:     Waiting for application startup.
#
# startup event
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8000 (Press CTRL+C to quit)
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [65019]
